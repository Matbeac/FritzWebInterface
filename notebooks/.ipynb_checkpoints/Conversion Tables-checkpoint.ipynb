# %%
import pandas as pd

inds = 'gram', 'milliliter', 'teaspoon', 'tablespoon', 'pound','ounce','pinch', 'squid', 'lemon','loaf',\
        'link','clove','sprig','leaf','bunch','pod','package','wedge','slice', '<unit>'
data = {['metric','to_Kg_multiplier']:[1/1000, 1/1000, 5/1000, 15/1000, 1/2.2, 1/35.274, 3/1000, 63/1000, 70/1000, 400/1000,\
        57/1000, 6/1000, 5/1000, 3/1000, 15/1000, 5/1000, 300/1000, 10/1000, 20/1000, 10/1000]}

conv_df = pd.DataFrame(data, index=inds)

# %%
conv_df.to_csv('conversion.csv')

# %%
conv_df
# Out:
#             to_Kg_multiplier
# gram                0.001000
# milliliter          0.001000
# teaspoon            0.005000
# tablespoon          0.015000
# pound               0.454545
# ounce               0.028349
# pinch               0.003000
# squid               0.063000
# lemon               0.070000
# loaf                0.400000
# link                0.057000
# clove               0.006000
# sprig               0.005000
# leaf                0.003000
# bunch               0.015000
# pod                 0.005000
# package             0.300000
# wedge               0.010000
# slice               0.020000
# <unit>              0.010000
